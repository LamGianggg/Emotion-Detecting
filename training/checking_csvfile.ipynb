# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import scipy
import seaborn
import IPython
import pandas as pd

# %% [markdown]
# Load Dataset

# %%
_base = os.getcwd()
_project_root = (
    os.path.dirname(_base) if os.path.basename(_base).lower() == "training" else _base
)
ALL_EMOTIONS_CSV = os.path.join(_project_root, "dataset", "all_emotions.csv")
ALL_EMOTIONS_CSV = os.path.normpath(ALL_EMOTIONS_CSV)

# %%
df = pd.read_csv(ALL_EMOTIONS_CSV)
df.value_counts("label")
# Out:
# label
# fear       9315
# anger      9315
# happy      9315
# disgust    9315
# sad        9310
# neutral    7915
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#             F0_mean        F0_std      F0_range  Energy_ mean   Energy_ std  \
# count  54485.000000  54485.000000  54485.000000  54485.000000  54485.000000
# mean     205.613005     52.312777    172.564908      0.023716      0.021837
# std      115.277987     91.734619    261.367990      0.023553      0.025184
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      137.953601     16.494055     61.046618      0.009555      0.006662
# 50%      193.042331     32.982320    117.841272      0.015605      0.012917
# 75%      244.303891     55.435179    189.777313      0.029039      0.026550
# max     2028.394580    879.656827   2027.598131      0.228895      0.219936
#
#            ZCR_mean       ZCR_std  Spectral_centroid_mean  \
# count  54485.000000  54485.000000            54485.000000
# mean       0.124542      0.089615             2266.268635
# std        0.085471      0.063706             1189.976223
# min        0.000000      0.000000                0.000000
# 25%        0.056431      0.033306             1287.936274
# 50%        0.088960      0.077713             1723.600403
# 75%        0.188398      0.131303             3187.278004
# max        0.492869      0.336733             7416.297748
#
#        Spectral_centroid_std  Spectral_flux_mean  ...  Delta_MFCC_C2_mean  \
# count           54485.000000        54485.000000  ...        54485.000000
# mean              922.341524            0.296512  ...           -0.035194
# std               621.025052            0.311927  ...            0.232973
# min                 0.000000            0.000000  ...           -2.814082
# 25%               429.720780            0.172271  ...           -0.079507
# 50%               743.696843            0.230257  ...           -0.010049
# 75%              1315.596491            0.291781  ...            0.043552
# max              4819.783067            3.990659  ...            2.080793
#
#        Delta_MFCC_C3_mean  Delta_MFCC_C4_mean  Delta_MFCC_C5_mean  \
# count        54485.000000        54485.000000        54485.000000
# mean            -0.007205            0.025366           -0.012671
# std              0.174379            0.168997            0.115846
# min             -2.113490           -1.854221           -1.266125
# 25%             -0.059144           -0.031940           -0.049782
# 50%             -0.005500            0.008841           -0.005118
# 75%              0.043772            0.058470            0.033632
# max              1.396789            1.676911            1.067473
#
#        Delta_MFCC_C0_std  Delta_MFCC_C1_std  Delta_MFCC_C2_std  \
# count       54485.000000       54485.000000       54485.000000
# mean           10.903517           5.345412           4.608628
# std             5.293045           2.313962           1.900098
# min             0.000006           0.000000           0.000000
# 25%             6.831969           3.622323           3.271949
# 50%            10.222263           4.796132           4.578399
# 75%            14.492401           6.695895           5.926492
# max            34.509930          18.036146          12.904985
#
#        Delta_MFCC_C3_std  Delta_MFCC_C4_std  Delta_MFCC_C5_std
# count       54485.000000       54485.000000       54485.000000
# mean            3.607400           3.216849           2.818085
# std             1.428755           1.182722           1.020924
# min             0.000000           0.000000           0.000000
# 25%             2.656204           2.355057           2.066060
# 50%             3.396323           3.133247           2.720504
# 75%             4.334468           4.009305           3.507054
# max             9.855183           8.510065           7.087403
#
# [8 rows x 48 columns]

# %% [markdown]
# Checking Duplication

# %%
df_fear = df[df['label'] == 'fear']
df_anger = df[df['label'] == 'anger']
df_happy = df[df['label'] == 'happy']
df_sad = df[df['label'] == 'sad']
df_neutral = df[df['label'] == 'neutral']
df_disgust = df[df['label'] == 'disgust']

print(f"fear : {df_fear.duplicated().sum()}")
print(f"anger : {df_anger.duplicated().sum()}")
print(f"happy : {df_happy.duplicated().sum()}")
print(f"sad : {df_sad.duplicated().sum()}")
print(f"neutral : {df_neutral.duplicated().sum()}")
print(f"disgust : {df_disgust.duplicated().sum()}")
# Out:
# fear : 0
# anger : 0
# happy : 0
# sad : 0
# neutral : 0
# disgust : 0

# %%
df_fear = df_fear.drop_duplicates()
df_sad = df_sad.drop_duplicates()

print(f"fear : {df_fear.duplicated().sum()}")
print(f"sad : {df_sad.duplicated().sum()}")

df = pd.concat([df_fear, df_anger, df_happy, df_sad, df_neutral, df_disgust])
# Out:
# fear : 0
# sad : 0

# %% [markdown]
# Null Checking

# %%
df.isna().sum()
# Out:
# F0_mean                   0
# F0_std                    0
# F0_range                  0
# Energy_ mean              0
# Energy_ std               0
# ZCR_mean                  0
# ZCR_std                   0
# Spectral_centroid_mean    0
# Spectral_centroid_std     0
# Spectral_flux_mean        0
# MFCC_C0_mean              0
# MFCC_C1_mean              0
# MFCC_C2_mean              0
# MFCC_C3_mean              0
# MFCC_C4_mean              0
# MFCC_C5_mean              0
# MFCC_C6_mean              0
# MFCC_C7_mean              0
# MFCC_C8_mean              0
# MFCC_C9_mean              0
# MFCC_C10_mean             0
# MFCC_C11_mean             0
# MFCC_C12_mean             0
# MFCC_C0_std               0
# MFCC_C1_std               0
# MFCC_C2_std               0
# MFCC_C3_std               0
# MFCC_C4_std               0
# MFCC_C5_std               0
# MFCC_C6_std               0
# MFCC_C7_std               0
# MFCC_C8_std               0
# MFCC_C9_std               0
# MFCC_C10_std              0
# MFCC_C11_std              0
# MFCC_C12_std              0
# Delta_MFCC_C0_mean        0
# Delta_MFCC_C1_mean        0
# Delta_MFCC_C2_mean        0
# Delta_MFCC_C3_mean        0
# Delta_MFCC_C4_mean        0
# Delta_MFCC_C5_mean        0
# Delta_MFCC_C0_std         0
# Delta_MFCC_C1_std         0
# Delta_MFCC_C2_std         0
# Delta_MFCC_C3_std         0
# Delta_MFCC_C4_std         0
# Delta_MFCC_C5_std         0
# label                     0
# dtype: int64

# %%
df["label"].value_counts()
# Out:
# label
# fear       9315
# anger      9315
# happy      9315
# disgust    9315
# sad        9310
# neutral    7915
# Name: count, dtype: int64

# %%
df.to_csv(ALL_EMOTIONS_CSV , index=False)
